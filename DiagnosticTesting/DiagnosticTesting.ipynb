# %%
from src.statistics import influence_of_prevalence_on_diagnostic_testing, influence_3ppv_of_prevalence_on_diagnostic_testing

# %% [markdown]
# Put in parameter values for the plot

# %%
min_prevalence = 10e-5
max_prevalence = 1

# %%
sensitivities = [0.99, 0.999, 0.99, 0.999]
specificities = [0.99, 0.99, 0.999, 0.999]

# %% [markdown]
# Plot figure comparing sensitivity, specificity, ppv and npv with disease prevalence

# %%
for sensitivity, specificity in zip(sensitivities,specificities):
    influence_of_prevalence_on_diagnostic_testing(
        sensitivity=sensitivity,
        specificity=specificity,
        min_prevalence=min_prevalence,
        max_prevalence=max_prevalence,
        save=True
    )
# Out:
# Saving plot to C:\Users\Surface\OneDrive\Documents\DataSpell\BIH-Scripts\DiagnosticTesting\data\out\InfluenceOfPrevalence_sensitivity0.990_specificty0.990.png...
# Saving plot to C:\Users\Surface\OneDrive\Documents\DataSpell\BIH-Scripts\DiagnosticTesting\data\out\InfluenceOfPrevalence_sensitivity0.999_specificty0.990.png...
# Saving plot to C:\Users\Surface\OneDrive\Documents\DataSpell\BIH-Scripts\DiagnosticTesting\data\out\InfluenceOfPrevalence_sensitivity0.990_specificty0.999.png...
# Saving plot to C:\Users\Surface\OneDrive\Documents\DataSpell\BIH-Scripts\DiagnosticTesting\data\out\InfluenceOfPrevalence_sensitivity0.999_specificty0.999.png...

# %%
sensitivities = [0.95, 0.99, 0.999]
specificities = sensitivities

influence_3ppv_of_prevalence_on_diagnostic_testing(
    sensitivities=sensitivities,
    specificities=specificities,
    min_prevalence=min_prevalence, max_prevalence=max_prevalence,
    save=True
)
# Out:
# Saving plot to C:\Users\Surface\OneDrive\Documents\DataSpell\BIH-Scripts\DiagnosticTesting\data\out\InfluenceOfPrevalence_0.950-0.950_0.990-0.990_0.999-0.999.png...
